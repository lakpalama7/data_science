# %%
# load dataset
# explore dataset
# indexing and filtering
# sorting
# column drop, rename, arrange

# %%
import pandas as pd

# %%
data = pd.read_csv(r"D:\my project\codeit_datascience\data_science\regression\data science\used_cars_data_uncleaned.csv")
data.head(2)
# Out:
#    S.No.                              Name Location  Year  Kilometers_Driven  \
# 0      0            Maruti Wagon R LXI CNG   Mumbai  2010              72000
# 1      1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015              41000
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine      Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0  58.16 bhp    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.2 bhp    5.0
#
#   New_Price  Price
# 0       NaN   1.75
# 1       NaN  12.50

# %%
# explore dataset

# %%
data.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0              72000       CNG       Manual      First    26.60   998.0
# 1              41000    Diesel       Manual      First    19.67  1582.0
# 2              46000    Petrol       Manual      First    18.20  1199.0
# 3              87000    Diesel       Manual      First    20.77  1248.0
# 4              40670    Diesel    Automatic     Second    15.20  1968.0
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# 2   88.7 bhp    5.0  8.61 Lakh   4.50
# ...

# %%
data.tail(2)
# Out:
#       S.No.                                               Name Location  Year  \
# 7251   7251                             Volkswagen Polo GT TSI     Pune  2013
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...    Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 7251              52262    Petrol    Automatic      Third     17.2  1197.0
# 7252              72443    Diesel    Automatic      First     10.0  2148.0
#
#           Power  Seats New_Price  Price
# 7251  103.6 bhp    5.0       NaN    NaN
# 7252    170 bhp    5.0       NaN    NaN

# %%
# dataset structure
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   str
#  2   Location           7253 non-null   str
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   str
#  6   Transmission       7253 non-null   str
#  7   Owner_Type         7253 non-null   str
#  8   Mileage            7251 non-null   float64
#  9   Engine             7207 non-null   float64
#  10  Power              7207 non-null   str
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   str
#  13  Price              6019 non-null   float64
# dtypes: float64(4), int64(3), str(7)
# memory usage: 793.4 KB

# %%
# statistical values
data.describe()
# Out:
#              S.No.         Year  Kilometers_Driven      Mileage       Engine  \
# count  7253.000000  7253.000000       7.253000e+03  7251.000000  7207.000000
# mean   3626.000000  2013.365366       5.869906e+04    18.141580  1616.573470
# std    2093.905084     3.254421       8.442772e+04     4.562197   595.285137
# min       0.000000  1996.000000       1.710000e+02     0.000000    72.000000
# 25%    1813.000000  2011.000000       3.400000e+04    15.170000  1198.000000
# 50%    3626.000000  2014.000000       5.341600e+04    18.160000  1493.000000
# 75%    5439.000000  2016.000000       7.300000e+04    21.100000  1968.000000
# max    7252.000000  2019.000000       6.500000e+06    33.540000  5998.000000
#
#              Seats        Price
# count  7200.000000  6019.000000
# mean      5.279722     9.479468
# std       0.811660    11.187917
# min       0.000000     0.440000
# 25%       5.000000     3.500000
# 50%       5.000000     5.640000
# 75%       5.000000     9.950000
# ...

# %%
# check null values
data.isna().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %%
# check columns
data.columns
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='str')

# %%
# check count values
data.value_counts(['Name'])
# Out:
# Name
# Mahindra XUV500 W8 2WD                55
# Maruti Swift VDI                      49
# Maruti Swift Dzire VDI                42
# Honda City 1.5 S MT                   39
# Maruti Swift VDI BSIV                 37
#                                       ..
# Skoda Superb Petrol Ambition           1
# Tata Tiago 1.05 Revotorq XT Option     1
# Ford EcoSport 1.5 Petrol Ambiente      1
# Jeep Compass 1.4 Sport                 1
# Hyundai Elite i20 Magna Plus           1
# Name: count, Length: 2041, dtype: int64

# %%
data.shape
# Out:
# (7253, 14)

# %%
data.ndim
# Out:
# 2

# %% [markdown]
# # indexing and filtering

# %%
data.head(2)
# Out:
#    S.No.                              Name Location  Year  Kilometers_Driven  \
# 0      0            Maruti Wagon R LXI CNG   Mumbai  2010              72000
# 1      1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015              41000
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine      Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0  58.16 bhp    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.2 bhp    5.0
#
#   New_Price  Price
# 0       NaN   1.75
# 1       NaN  12.50

# %%
# loc() and iloc()
# loc() -- use index and column name

# %%
# get first 5 rows and first 5 columns using iloc()
data.iloc[0:5,0:5]
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven
# 0              72000
# 1              41000
# 2              46000
# 3              87000
# 4              40670

# %%
# get index 40 to 45 rows and columns 'Name','Engine' only using loc
data.loc[40:45,['Name','Engine']]
# Out:
#                                          Name  Engine
# 40                            Maruti Alto LXi   796.0
# 41                            Tata Nano LX SE   624.0
# 42  Mahindra KUV 100 mFALCON D75 K8 Dual Tone  1198.0
# 43             Hyundai i20 Magna Optional 1.2  1197.0
# 44           Hyundai Elantra 2.0 SX Option AT  1999.0
# 45                  Toyota Corolla Altis G AT  1798.0

# %%
# get last three rows and three columns
data.iloc[-1:-4:-1,0:3]
# Out:
#       S.No.                                               Name Location
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...    Kochi
# 7251   7251                             Volkswagen Polo GT TSI     Pune
# 7250   7250                             Nissan Micra Diesel XV  Kolkata

# %%
# get rows from 10 to 30 in step 3 and column 5 to 10
data.iloc[10:30:3, 5:10]
# Out:
#    Fuel_Type Transmission Owner_Type  Mileage  Engine
# 10    Petrol       Manual      First    21.56  1462.0
# 13    Diesel    Automatic      First    12.70  2179.0
# 16    Diesel       Manual      First    25.80  1498.0
# 19    Diesel    Automatic      First    14.84  2143.0
# 22    Petrol    Automatic      First    13.53  1984.0
# 25    Petrol       Manual      First    16.80  1497.0
# 28    Petrol       Manual      First    17.50  1199.0

# %%
data['Name'].head()
# Out:
# 0              Maruti Wagon R LXI CNG
# 1    Hyundai Creta 1.6 CRDi SX Option
# 2                        Honda Jazz V
# 3                   Maruti Ertiga VDI
# 4     Audi A4 New 2.0 TDI Multitronic
# Name: Name, dtype: str

# %%
data[['Name','Year']]
# Out:
#                                                    Name  Year
# 0                                Maruti Wagon R LXI CNG  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option  2015
# 2                                          Honda Jazz V  2011
# 3                                     Maruti Ertiga VDI  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  2013
# ...                                                 ...   ...
# 7248                  Volkswagen Vento Diesel Trendline  2011
# 7249                             Volkswagen Polo GT TSI  2015
# 7250                             Nissan Micra Diesel XV  2012
# 7251                             Volkswagen Polo GT TSI  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...  2014
#
# [7253 rows x 2 columns]

# %%
data.head(2)
# Out:
#    S.No.                              Name Location  Year  Kilometers_Driven  \
# 0      0            Maruti Wagon R LXI CNG   Mumbai  2010              72000
# 1      1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015              41000
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine      Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0  58.16 bhp    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.2 bhp    5.0
#
#   New_Price  Price
# 0       NaN   1.75
# 1       NaN  12.50

# %%
# get Mileage >=30
con1 = data['Mileage']>=30
data[con1]
# Out:
#       S.No.                               Name Location  Year  \
# 1269   1269  Maruti Alto 800 2016-2019 CNG LXI   Mumbai  2018
# 1332   1332             Maruti Wagon R CNG LXI     Pune  2013
# 2059   2059             Maruti Wagon R CNG LXI   Mumbai  2013
# 2371   2371             Maruti Wagon R CNG LXI     Pune  2014
# 2701   2701          Maruti Celerio CNG VXI MT    Kochi  2016
# 3119   3119   Maruti Alto K10 LXI CNG Optional    Kochi  2018
# 3129   3129             Maruti Wagon R CNG LXI    Delhi  2014
# 3553   3553  Maruti Alto 800 2016-2019 CNG LXI     Pune  2015
# 3869   3869  Maruti Alto 800 2016-2019 CNG LXI    Delhi  2012
# 4141   4141             Maruti Wagon R CNG LXI   Mumbai  2014
# 4769   4769  Maruti Alto 800 2016-2019 CNG LXI    Kochi  2017
# 5178   5178          Maruti Celerio CNG VXI MT    Delhi  2015
# 5710   5710            Maruti Alto 800 CNG LXI   Mumbai  2013
# 5935   5935            Maruti Alto K10 LXI CNG     Pune  2015
# ...

# %%
# get Mileage >=32 and Transmission is manual
con1 = data['Mileage']>=32
con2 = data['Transmission']=='Manual'
data[con1 & con2]
# Out:
#       S.No.                               Name Location  Year  \
# 1269   1269  Maruti Alto 800 2016-2019 CNG LXI   Mumbai  2018
# 1332   1332             Maruti Wagon R CNG LXI     Pune  2013
# 2059   2059             Maruti Wagon R CNG LXI   Mumbai  2013
# 2371   2371             Maruti Wagon R CNG LXI     Pune  2014
# 3119   3119   Maruti Alto K10 LXI CNG Optional    Kochi  2018
# 3129   3129             Maruti Wagon R CNG LXI    Delhi  2014
# 3553   3553  Maruti Alto 800 2016-2019 CNG LXI     Pune  2015
# 3869   3869  Maruti Alto 800 2016-2019 CNG LXI    Delhi  2012
# 4141   4141             Maruti Wagon R CNG LXI   Mumbai  2014
# 4769   4769  Maruti Alto 800 2016-2019 CNG LXI    Kochi  2017
# 5935   5935            Maruti Alto K10 LXI CNG     Pune  2015
# 6019   6019            Maruti Alto K10 LXI CNG    Delhi  2014
# 6538   6538            Maruti Alto K10 LXI CNG    Kochi  2015
# 6788   6788   Maruti Alto K10 LXI CNG Optional    Delhi  2017
#
# ...

# %%
data[(data['Mileage']>=32) & (data['Transmission']=='Manual')]
# Out:
#       S.No.                               Name Location  Year  \
# 1269   1269  Maruti Alto 800 2016-2019 CNG LXI   Mumbai  2018
# 1332   1332             Maruti Wagon R CNG LXI     Pune  2013
# 2059   2059             Maruti Wagon R CNG LXI   Mumbai  2013
# 2371   2371             Maruti Wagon R CNG LXI     Pune  2014
# 3119   3119   Maruti Alto K10 LXI CNG Optional    Kochi  2018
# 3129   3129             Maruti Wagon R CNG LXI    Delhi  2014
# 3553   3553  Maruti Alto 800 2016-2019 CNG LXI     Pune  2015
# 3869   3869  Maruti Alto 800 2016-2019 CNG LXI    Delhi  2012
# 4141   4141             Maruti Wagon R CNG LXI   Mumbai  2014
# 4769   4769  Maruti Alto 800 2016-2019 CNG LXI    Kochi  2017
# 5935   5935            Maruti Alto K10 LXI CNG     Pune  2015
# 6019   6019            Maruti Alto K10 LXI CNG    Delhi  2014
# 6538   6538            Maruti Alto K10 LXI CNG    Kochi  2015
# 6788   6788   Maruti Alto K10 LXI CNG Optional    Delhi  2017
#
# ...

# %%
data[con1 & con2][['Name','Year']]
# Out:
#                                    Name  Year
# 1269  Maruti Alto 800 2016-2019 CNG LXI  2018
# 1332             Maruti Wagon R CNG LXI  2013
# 2059             Maruti Wagon R CNG LXI  2013
# 2371             Maruti Wagon R CNG LXI  2014
# 3119   Maruti Alto K10 LXI CNG Optional  2018
# 3129             Maruti Wagon R CNG LXI  2014
# 3553  Maruti Alto 800 2016-2019 CNG LXI  2015
# 3869  Maruti Alto 800 2016-2019 CNG LXI  2012
# 4141             Maruti Wagon R CNG LXI  2014
# 4769  Maruti Alto 800 2016-2019 CNG LXI  2017
# 5935            Maruti Alto K10 LXI CNG  2015
# 6019            Maruti Alto K10 LXI CNG  2014
# 6538            Maruti Alto K10 LXI CNG  2015
# 6788   Maruti Alto K10 LXI CNG Optional  2017

# %%
data.sample(n=10) # generate 10 rows randomly
# Out:
#       S.No.                               Name    Location  Year  \
# 108     108             Mahindra XUV500 W8 2WD       Delhi  2012
# 2112   2112          Hyundai Creta 1.6 CRDi SX      Jaipur  2015
# 4574   4574   Hyundai Creta 1.6 CRDi SX Option   Bangalore  2016
# 497     497                Maruti Zen LXi BSII     Chennai  2004
# 1419   1419             Hyundai Santro Xing XL     Chennai  2007
# 5928   5928              Mahindra NuvoSport N6  Coimbatore  2018
# 7183   7183              Hyundai Verna CRDi SX   Hyderabad  2009
# 6208   6208          Audi Q5 2008-2012 2.0 TDI  Coimbatore  2012
# 1056   1056    Maruti S-Cross Zeta DDiS 200 SH  Coimbatore  2016
# 5262   5262  Tata Tiago 1.2 Revotron XM Option     Chennai  2016
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 108               65000    Diesel       Manual     Second    16.00  2179.0
# 2112              83950    Diesel       Manual      First    19.67  1582.0
# ...

# %%
data.sample(frac=0.01) # generate 1 % of total records
# Out:
#       S.No.                                  Name    Location  Year  \
# 4764   4764               Hyundai EON D Lite Plus  Coimbatore  2016
# 5954   5954                Toyota Fortuner 4x4 AT     Chennai  2015
# 5326   5326           Hyundai i20 1.2 Asta Option   Bangalore  2016
# 5405   5405  Audi Q7 3.0 TDI Quattro Premium Plus       Delhi  2014
# 1982   1982                   Honda A ord 2.4 A/T      Mumbai  2011
# ...     ...                                   ...         ...   ...
# 2784   2784                Nissan Micra Diesel XV   Hyderabad  2011
# 470     470                     Maruti Ciaz 1.3 S  Coimbatore  2017
# 696     696        Volkswagen Passat Highline DSG     Kolkata  2012
# 6319   6319           Maruti Zen Estilo LXI BS IV        Pune  2010
# 4963   4963                Maruti Swift Vdi BSIII      Jaipur  2010
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# ...

# %%
data.columns
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='str')

# %%
data['Name'].unique()
# Out:
# <StringArray>
# [                 'Maruti Wagon R LXI CNG',
#         'Hyundai Creta 1.6 CRDi SX Option',
#                             'Honda Jazz V',
#                        'Maruti Ertiga VDI',
#          'Audi A4 New 2.0 TDI Multitronic',
#          'Hyundai EON LPG Era Plus Option',
#                   'Nissan Micra Diesel XV',
#        'Toyota Innova Crysta 2.8 GX AT 8S',
#      'Volkswagen Vento Diesel Comfortline',
#           'Tata Indica Vista Quadrajet LS',
#  ...
#    'Mercedes-Benz S Class 2005 2013 320 L',
#                        'Maruti Alto XCITE',
#  'Land Rover Discovery 4 TDV6 Auto Diesel',
#  'Hyundai Verna Transform VTVT with Audio',
#        'Maruti Vitara Brezza ZDi Plus AMT',
#             'Skoda Superb Petrol Ambition',
#       'Tata Tiago 1.05 Revotorq XT Option',
#        'Ford EcoSport 1.5 Petrol Ambiente',
#                   'Jeep Compass 1.4 Sport',
#             'Hyundai Elite i20 Magna Plus']
# Length: 2041, dtype: str

# %%
data['Name'].nunique()
# Out:
# 2041

# %%
data.Transmission.unique()
# Out:
# <StringArray>
# ['Manual', 'Automatic']
# Length: 2, dtype: str

# %%
data.Transmission.nunique()
# Out:
# 2

# %%
data[data['Transmission']=='Automatic']
# Out:
#       S.No.                                               Name    Location  \
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# 7         7                  Toyota Innova Crysta 2.8 GX AT 8S      Mumbai
# 11       11                        Honda City 1.5 V AT Sunroof     Kolkata
# 13       13                   Land Rover Range Rover 2.2L Pure       Delhi
# 14       14                     Land Rover Freelander 2 TD4 SE        Pune
# ...     ...                                                ...         ...
# 7241   7241                            BMW 5 Series 525d Sedan       Delhi
# 7246   7246                          Hyundai Grand i10 AT Asta  Coimbatore
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
data.Location.nunique()
# Out:
# 11

# %%
data.Location.unique()
# Out:
# <StringArray>
# [    'Mumbai',       'Pune',    'Chennai', 'Coimbatore',  'Hyderabad',
#      'Jaipur',      'Kochi',    'Kolkata',      'Delhi',  'Bangalore',
#   'Ahmedabad']
# Length: 11, dtype: str

# %%
data['Location'].value_counts()
# Out:
# Location
# Mumbai        949
# Hyderabad     876
# Coimbatore    772
# Kochi         772
# Pune          765
# Delhi         660
# Kolkata       654
# Chennai       591
# Jaipur        499
# Bangalore     440
# Ahmedabad     275
# Name: count, dtype: int64

# %%
data[data.Location=='Pune']
# Out:
#       S.No.                                       Name Location  Year  \
# 1         1           Hyundai Creta 1.6 CRDi SX Option     Pune  2015
# 8         8        Volkswagen Vento Diesel Comfortline     Pune  2013
# 14       14             Land Rover Freelander 2 TD4 SE     Pune  2012
# 38       38           Mercedes-Benz M-Class ML 350 CDI     Pune  2013
# 63       63  Mercedes-Benz New C-Class 200 CDI Classic     Pune  2011
# ...     ...                                        ...      ...   ...
# 7200   7200                            Maruti Ritz LDi     Pune  2015
# 7228   7228         Tata Tiago 1.05 Revotorq XT Option     Pune  2016
# 7230   7230                      Hyundai i20 1.2 Spotz     Pune  2014
# 7244   7244                      Chevrolet Aveo 1.4 LS     Pune  2009
# 7251   7251                     Volkswagen Polo GT TSI     Pune  2013
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# ...

# %%
# get not manual
data[data.Transmission !='Manual']
# Out:
#       S.No.                                               Name    Location  \
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# 7         7                  Toyota Innova Crysta 2.8 GX AT 8S      Mumbai
# 11       11                        Honda City 1.5 V AT Sunroof     Kolkata
# 13       13                   Land Rover Range Rover 2.2L Pure       Delhi
# 14       14                     Land Rover Freelander 2 TD4 SE        Pune
# ...     ...                                                ...         ...
# 7241   7241                            BMW 5 Series 525d Sedan       Delhi
# 7246   7246                          Hyundai Grand i10 AT Asta  Coimbatore
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
data[data['Transmission']!='Manual'].Transmission.value_counts()
# Out:
# Transmission
# Automatic    2049
# Name: count, dtype: int64

# %%
data[data['Transmission']!='Manual'].Transmission.value_counts()
# Out:
# Transmission
# Automatic    2049
# Name: count, dtype: int64

# %%
data.Transmission.value_counts()
# Out:
# Transmission
# Manual       5204
# Automatic    2049
# Name: count, dtype: int64

# %% [markdown]
# # Sorting

# %%
data.sort_values(by='Name')
# Out:
#       S.No.                            Name   Location  Year  \
# 1221   1221  Ambassador Classic Nova Diesel    Chennai  2003
# 6663   6663       Audi A3 35 TDI Attraction  Ahmedabad  2014
# 398     398       Audi A3 35 TDI Attraction    Chennai  2014
# 4782   4782          Audi A3 35 TDI Premium     Mumbai  2016
# 6742   6742     Audi A3 35 TDI Premium Plus  Hyderabad  2015
# ...     ...                             ...        ...   ...
# 1178   1178       Volvo XC60 D5 Inscription      Kochi  2014
# 4497   4497  Volvo XC90 2007-2015 D5 AT AWD      Kochi  2014
# 6384   6384     Volvo XC90 2007-2015 D5 AWD  Bangalore  2016
# 2401   2401     Volvo XC90 2007-2015 D5 AWD      Kochi  2014
# 6659   6659     Volvo XC90 2007-2015 D5 AWD      Delhi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 1221              80000    Diesel       Manual      Third    12.80  1489.0
# 6663              84004    Diesel    Automatic      First    20.38  1968.0
# ...

# %%
data.sort_values(by='Transmission')
# Out:
#       S.No.                                               Name    Location  \
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
# 5595   5595            BMW 5 Series 2013-2017 520d Luxury Line      Jaipur
# 2355   2355          Mercedes-Benz GLA Class 200 Sport Edition       Delhi
# 2357   2357                Mercedes-Benz CLA 200 Sport Edition       Delhi
# 5587   5587                        BMW X1 sDrive 20d Sportline     Kolkata
# ...     ...                                                ...         ...
# 2836   2836                                 Tata Indigo CS eVX     Chennai
# 2834   2834                              Maruti Swift VDI BSIV     Chennai
# 2832   2832                            Tata Zest Quadrajet 1.3       Kochi
# 2848   2848                           Maruti Wagon R LXI BS IV       Delhi
# 3626   3626                               Ford Figo Diesel ZXI  Coimbatore
#
# ...

# %%
# multilevel sorting
data.sort_values(by=['Location','Mileage'])
# Out:
#       S.No.                                      Name   Location  Year  \
# 194     194                        Honda City 1.5 GXI  Ahmedabad  2007
# 3061   3061                         Hyundai Santro GS  Ahmedabad  2005
# 5374   5374       Mercedes-Benz M-Class ML 350 4Matic  Ahmedabad  2012
# 5875   5875  Mercedes-Benz C-Class Progressive C 220d  Ahmedabad  2019
# 6090   6090                    Hyundai Santro Xing GL  Ahmedabad  2013
# ...     ...                                       ...        ...   ...
# 5940   5940                          Maruti Dzire LDI       Pune  2018
# 5935   5935                   Maruti Alto K10 LXI CNG       Pune  2015
# 3553   3553         Maruti Alto 800 2016-2019 CNG LXI       Pune  2015
# 1332   1332                    Maruti Wagon R CNG LXI       Pune  2013
# 2371   2371                    Maruti Wagon R CNG LXI       Pune  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# ...

# %%
data.sort_values(by=['Location','Mileage'], ascending=False)
# Out:
#       S.No.                                      Name   Location  Year  \
# 1332   1332                    Maruti Wagon R CNG LXI       Pune  2013
# 2371   2371                    Maruti Wagon R CNG LXI       Pune  2014
# 3553   3553         Maruti Alto 800 2016-2019 CNG LXI       Pune  2015
# 5935   5935                   Maruti Alto K10 LXI CNG       Pune  2015
# 1756   1756                     Maruti Swift DDiS VDI       Pune  2008
# ...     ...                                       ...        ...   ...
# 5374   5374       Mercedes-Benz M-Class ML 350 4Matic  Ahmedabad  2012
# 5875   5875  Mercedes-Benz C-Class Progressive C 220d  Ahmedabad  2019
# 6090   6090                    Hyundai Santro Xing GL  Ahmedabad  2013
# 6205   6205                    Hyundai Santro Xing GL  Ahmedabad  2007
# 7226   7226                    Hyundai Santro Xing GL  Ahmedabad  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# ...

# %%
data.sort_values(by=['Location','Year'])[['Name','Location']]
# Out:
#                                         Name   Location
# 1318                      Honda City 1.3 EXI  Ahmedabad
# 3200                 Maruti Wagon R LX BSIII  Ahmedabad
# 3061                       Hyundai Santro GS  Ahmedabad
# 5843               Maruti Esteem Vxi - BSIII  Ahmedabad
# 194                       Honda City 1.5 GXI  Ahmedabad
# ...                                      ...        ...
# 5940                        Maruti Dzire LDI       Pune
# 5941                        Renault KWID RXL       Pune
# 6155          Jaguar XE 2.0L Diesel Prestige       Pune
# 5339  Hyundai i20 Active SX Dual Tone Petrol       Pune
# 6529                       Honda Jazz VX CVT       Pune
#
# [7253 rows x 2 columns]

# %%
data.Mileage.value_counts()
# Out:
# Mileage
# 17.00    208
# 18.90    201
# 18.60    144
# 21.10    107
# 20.36    105
#         ...
# 20.80      1
# 11.88      1
# 12.08      1
# 15.56      1
# 17.15      1
# Name: count, Length: 438, dtype: int64

# %%
data.Fuel_Type.unique()
# Out:
# <StringArray>
# ['CNG', 'Diesel', 'Petrol', 'LPG', 'Electric']
# Length: 5, dtype: str

# %%
data.Fuel_Type.nunique()
# Out:
# 5

# %%
data.Fuel_Type.value_counts()
# Out:
# Fuel_Type
# Diesel      3852
# Petrol      3325
# CNG           62
# LPG           12
# Electric       2
# Name: count, dtype: int64

# %%
data.Mileage.min()
# Out:
# np.float64(0.0)

# %%
data.Mileage.max()
# Out:
# np.float64(33.54)

# %%
data.Mileage.mean()
# Out:
# np.float64(18.141580471659083)

# %%
data.Mileage.std()
# Out:
# np.float64(4.562196601725892)

# %%
data.Mileage.median()
# Out:
# np.float64(18.16)

# %%
data.Mileage.quantile(0.25)
# Out:
# np.float64(15.17)

# %%
data.Mileage.quantile(0.75)
# Out:
# np.float64(21.1)

# %%
data.Mileage.sum()
# Out:
# np.float64(131544.6)

# %% [markdown]
# # column rename, drop , arrange

# %%
data.columns
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='str')

# %%
data.drop('S.No.', axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='str')

# %%
data.drop(columns=['Power','Seats'], inplace=True)

# %%
data.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'New_Price',
#        'Price'],
#       dtype='str')

# %%
data.rename(columns={'Kilometers_Driven':'distance','Fuel_Type':'fule','New_Price':'price'}, inplace=True)

# %%
data.columns
# Out:
# Index(['Name', 'Location', 'Year', 'distance', 'fule', 'Transmission',
#        'Owner_Type', 'Mileage', 'Engine', 'price', 'Price'],
#       dtype='str')

# %%
# rearrange column
col = ['Year','Location','Name','distance', 'fule', 'Transmission',
       'Owner_Type', 'Mileage', 'Engine', 'price', 'Price']

# %%
data = data[col]

# %%
# save data
data.to_csv('saveddata.csv',inde
