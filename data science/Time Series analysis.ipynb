# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel(r"D:\my project\codeit_datascience\course data\Ecommerce Sales Data.xlsx")
data.head()
# Out:
#    Row ID        Order ID  Year           Order Date            Ship Date  \
# 0       1  CA-2013-152156  2013  2013-09-11 00:00:00  2013-12-11 00:00:00
# 1       2  CA-2013-152156  2013  2013-09-11 00:00:00  2013-12-11 00:00:00
# 2       3  CA-2013-138688  2013            6/13/2013            6/17/2013
# 3       4  US-2012-108966  2012  2012-11-10 00:00:00           10/18/2012
# 4       5  US-2012-108966  2012  2012-11-10 00:00:00           10/18/2012
#
#         Ship Mode Customer ID    Customer Name    Segment        Country  ...  \
# 0    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 1    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 2    Second Class    DV-13045  Darrin Van Huff  Corporate  United States  ...
# 3  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
# 4  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Year           9994 non-null   int64
#  3   Order Date     9994 non-null   object
#  4   Ship Date      9994 non-null   object
#  5   Ship Mode      9994 non-null   str
#  6   Customer ID    9994 non-null   str
#  7   Customer Name  9994 non-null   str
#  8   Segment        9994 non-null   str
#  9   Country        9994 non-null   str
#  10  City           9994 non-null   str
#  11  State          9994 non-null   str
#  12  Postal Code    9994 non-null   int64
#  13  Region         9994 non-null   str
#  14  Product ID     9994 non-null   str
#  15  Category       9994 non-null   str
#  16  Sub-Category   9994 non-null   str
#  17  Product Name   9994 non-null   str
# ...

# %%
# set 'oreder date' and 'ship date' to datetime form
data['Order Date']=pd.to_datetime(data['Order Date'])

# %%
data['Ship Date'] = pd.to_datetime(data['Ship Date'])

# %%
data[['Order Date', 'Ship Date']].info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order Date  9994 non-null   datetime64[us]
#  1   Ship Date   9994 non-null   datetime64[us]
# dtypes: datetime64[us](2)
# memory usage: 156.3 KB

# %%
data.head(2)
# Out:
#    Row ID        Order ID  Year Order Date  Ship Date     Ship Mode  \
# 0       1  CA-2013-152156  2013 2013-09-11 2013-12-11  Second Class
# 1       2  CA-2013-152156  2013 2013-09-11 2013-12-11  Second Class
#
#   Customer ID Customer Name   Segment        Country  ... Postal Code Region  \
# 0    CG-12520   Claire Gute  Consumer  United States  ...       42420  South
# 1    CG-12520   Claire Gute  Consumer  United States  ...       42420  South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94        3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 22 columns]

# %% [markdown]
# # components of datetime

# %%
# year -- dt.year --- get only year
data['Order Date'].dt.year
# Out:
# 0       2013
# 1       2013
# 2       2013
# 3       2012
# 4       2012
#         ...
# 9989    2011
# 9990    2014
# 9991    2014
# 9992    2014
# 9993    2014
# Name: Order Date, Length: 9994, dtype: int32

# %%
data['Order Date'].dt.month
# Out:
# 0        9
# 1        9
# 2        6
# 3       11
# 4       11
#         ..
# 9989     1
# 9990     2
# 9991     2
# 9992     2
# 9993     5
# Name: Order Date, Length: 9994, dtype: int32

# %%
data['Order Date'].dt.day
# Out:
# 0       11
# 1       11
# 2       13
# 3       10
# 4       10
#         ..
# 9989    22
# 9990    27
# 9991    27
# 9992    27
# 9993     5
# Name: Order Date, Length: 9994, dtype: int32

# %%
# Get month name
data['Order Date'].dt.month_name()
# Out:
# 0       September
# 1       September
# 2            June
# 3        November
# 4        November
#           ...
# 9989      January
# 9990     February
# 9991     February
# 9992     February
# 9993          May
# Name: Order Date, Length: 9994, dtype: str

# %%
# get Day name
data['Order Date'].dt.day_name()
# Out:
# 0       Wednesday
# 1       Wednesday
# 2        Thursday
# 3        Saturday
# 4        Saturday
#           ...
# 9989     Saturday
# 9990     Thursday
# 9991     Thursday
# 9992     Thursday
# 9993       Monday
# Name: Order Date, Length: 9994, dtype: str

# %% [markdown]
# # Mathmatcial Operations on Date

# %%
data[['Order Date','Ship Date']]
# Out:
#      Order Date  Ship Date
# 0    2013-09-11 2013-12-11
# 1    2013-09-11 2013-12-11
# 2    2013-06-13 2013-06-17
# 3    2012-11-10 2012-10-18
# 4    2012-11-10 2012-10-18
# ...         ...        ...
# 9989 2011-01-22 2011-01-24
# 9990 2014-02-27 2014-04-03
# 9991 2014-02-27 2014-04-03
# 9992 2014-02-27 2014-04-03
# 9993 2014-05-05 2014-10-05
#
# [9994 rows x 2 columns]

# %%
# find delay date between 'order date' and 'ship date'
data['Ship Date'] - data['Order Date']
# Out:
# 0       91 days
# 1       91 days
# 2        4 days
# 3      -23 days
# 4      -23 days
#          ...
# 9989     2 days
# 9990    35 days
# 9991    35 days
# 9992    35 days
# 9993   153 days
# Length: 9994, dtype: timedelta64[us]

# %%
# Add Days
# add 5 days in column 'Order date'
data['Order Date'] + pd.Timedelta(days=5)
# Out:
# 0      2013-09-16
# 1      2013-09-16
# 2      2013-06-18
# 3      2012-11-15
# 4      2012-11-15
#           ...
# 9989   2011-01-27
# 9990   2014-03-04
# 9991   2014-03-04
# 9992   2014-03-04
# 9993   2014-05-10
# Name: Order Date, Length: 9994, dtype: datetime64[us]

# %%
# add month -- pd.DateOffset(months=...)
data['Order Date'] + pd.DateOffset(months=4)
# Out:
# 0      2014-01-11
# 1      2014-01-11
# 2      2013-10-13
# 3      2013-03-10
# 4      2013-03-10
#           ...
# 9989   2011-05-22
# 9990   2014-06-27
# 9991   2014-06-27
# 9992   2014-06-27
# 9993   2014-09-05
# Name: Order Date, Length: 9994, dtype: datetime64[us]

# %%
# add years
data['Order Date'] + pd.DateOffset(years=2)
# Out:
# 0      2015-09-11
# 1      2015-09-11
# 2      2015-06-13
# 3      2014-11-10
# 4      2014-11-10
#           ...
# 9989   2013-01-22
# 9990   2016-02-27
# 9991   2016-02-27
# 9992   2016-02-27
# 9993   2016-05-05
# Name: Order Date, Length: 9994, dtype: datetime64[us]

# %%
data['Ship Date'].dt.year
# Out:
# 0       2013
# 1       2013
# 2       2013
# 3       2012
# 4       2012
#         ...
# 9989    2011
# 9990    2014
# 9991    2014
# 9992    2014
# 9993    2014
# Name: Ship Date, Length: 9994, dtype: int32

# %%
data['Ship Date'].dt.month
# Out:
# 0       12
# 1       12
# 2        6
# 3       10
# 4       10
#         ..
# 9989     1
# 9990     4
# 9991     4
# 9992     4
# 9993    10
# Name: Ship Date, Length: 9994, dtype: int32

# %%
data['Ship Date'].dt.day
# Out:
# 0       11
# 1       11
# 2       17
# 3       18
# 4       18
#         ..
# 9989    24
# 9990     3
# 9991     3
# 9992     3
# 9993     5
# Name: Ship Date, Length: 9994, dtype: int32

# %%
data['Ship Date'].dt.month_name()
# Out:
# 0       December
# 1       December
# 2           June
# 3        October
# 4        October
#           ...
# 9989     January
# 9990       April
# 9991       April
# 9992       April
# 9993     October
# Name: Ship Date, Length: 9994, dtype: str

# %%
data['Ship Date'].dt.day_name()
# Out:
# 0       Wednesday
# 1       Wednesday
# 2          Monday
# 3        Thursday
# 4        Thursday
#           ...
# 9989       Monday
# 9990     Thursday
# 9991     Thursday
# 9992     Thursday
# 9993       Sunday
# Name: Ship Date, Length: 9994, dtype: str

# %%
data['Ship Date']
# Out:
# 0      2013-12-11
# 1      2013-12-11
# 2      2013-06-17
# 3      2012-10-18
# 4      2012-10-18
#           ...
# 9989   2011-01-24
# 9990   2014-04-03
# 9991   2014-04-03
# 9992   2014-04-03
# 9993   2014-10-05
# Name: Ship Date, Length: 9994, dtype: datetime64[us]

# %%
data['Ship Date'] + pd
