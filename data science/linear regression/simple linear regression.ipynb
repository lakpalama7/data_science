# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"homeprices.csv")
data
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(data['area'], data.price)
plt.xlabel("Area")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
X = data.drop('price', axis='columns')
X
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
y = data.price
y
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
lr.predict([[4000]])
# Out:
# D:\my project\codeit_datascience\data_science\venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([723767.12328767])

# %%
lr.predict(X.iloc[0].values.reshape(1,1))
# Out:
# D:\my project\codeit_datascience\data_science\venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([533664.38356164])

# %%
m = lr.coef_
m
# Out:
# array([135.78767123])

# %%
c = lr.intercept_
c
# Out:
# np.float64(180616.43835616432)

# %%
# y= mx + c
m * 2600 + c
# Out:
# array([533664.38356164])

# %%
plt.scatter(data.area, data.price)
plt.plot(data.area,lr.predict(data[['area']]), color='red')
plt.xlabel('Area')
plt.ylabel('Price')
plt.title("Area and price linear regression")
plt.show()

# %%
lr.predict(X)
# Out:
# array([533664.38356164, 587979.45205479, 615136.98630137, 669452.05479452,
#        723767.12328767])

# %%
# predict the price based on areas
test = pd.read_csv(r"areas.csv")
test
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
# use the 'lr' model and predict the price
lr.predict(test)
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
test['price'] = lr.predict(test)
test
# Out:
#     area         price
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
test['price'] = test.price.apply(lambda x:f"{x:.1f}")
test
# Out:
#     area      price
# 0   1000   316404.1
# 1   1500   384297.9
# 2   2300   492928.1
# 3   3540   661304.8
# 4   4120   740061.6
# 5   4560   799808.2
# 6   5490   926090.8
# 7   3460   650441.8
# 8   4750   825607.9
# 9   2300   492928.1
# 10  9000  1402705.5
# 11  8600  1348390.4
# 12  7100  1144708.9

# %%
test.to_csv('price_prediction.csv', index=False)
