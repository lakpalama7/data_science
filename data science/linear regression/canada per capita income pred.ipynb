# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"canada_per_capita_income.csv")
data.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
plt.scatter(data.year, data['per capita income (US$)'])

# %%
data = data.rename(columns={'per capita income (US$)':'income'})

# %%
data.head()
# Out:
#    year       income
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
X = data.drop('income', axis='columns')
X.head()
# Out:
#    year
# 0  1970
# 1  1971
# 2  1972
# 3  1973
# 4  1974

# %%
y = data.income
y.head()
# Out:
# 0    3399.299037
# 1    3768.297935
# 2    4251.175484
# 3    4804.463248
# 4    5576.514583
# Name: income, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr
# Out:
# LinearRegression()

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
lr.predict([[2020]])
# Out:
# D:\my project\codeit_datascience\data_science\venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %% [raw]
# predict the per capita income fo canadian citizens in year 2020
# Answer
# 41288.69409442

# %%
plt.scatter(data.year, data.income)
plt.plot(data.year, lr.predict(data[['year']]), color='red')
plt.xlabel('Year')
plt.ylabel('Income (US)')
plt.title('Candian per capita income')
plt.show()

# %%
sns.boxplot(data=data, y=data.income)
# Out:
# <Axes: ylabel='income'>

# %%
sns.kdeplot(data=data, x=data.year)
# Out:
# <Axes: xlabel='year', ylabel='Density'>

# %%
sns.histplot(data=data, x=data.year, kde=True)
# Out:
# <Axes: xlabel='year', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=data.year,y=data.income)
plt.tight_layout()
plt.xticks(rotation=90)
plt.show()
