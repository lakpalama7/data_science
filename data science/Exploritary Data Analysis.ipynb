# %% [markdown]
# # Exploritary Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\my project\codeit_datascience\data_science\regression\data science\coaster_db.csv")
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# ...

# %% [raw]
# Step 1: Data understanding
# - Dataframe shape
# - head and tail
# - dtypes
# - describe

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.head(2)
# Out:
#          coaster_name          Length             Speed       Location  \
# 0  Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)   Coney Island
# 1   Flip Flap Railway             NaN               NaN  Sea Lion Park
#
#     Status   Opening date  Type            Manufacturer Height restriction  \
# 0  Removed  June 16, 1884  Wood  LaMarcus Adna Thompson                NaN
# 1  Removed           1895  Wood            Lina Beecher                NaN
#
#          Model  ...  speed1    speed2 speed1_value speed1_unit speed_mph  \
# 0  Lift Packed  ...  6 mph   9.7 km/h          6.0         mph       6.0
# 1          NaN  ...     NaN       NaN          NaN         NaN       NaN
#
#   height_value height_unit height_ft Inversions_clean Gforce_clean
# 0         50.0          ft       NaN                0          2.9
# 1          NaN         NaN       NaN                1         12.0
#
# [2 rows x 56 columns]

# %%
df.tail(3)
# Out:
#                         coaster_name                Length  \
# 1084       Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                         Tumbili        770 ft (230 m)
# 1086  Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                  Location              Status  \
# 1084  59.3[1] mph (95.4 km/h)                     Other                 NaN
# 1085         34 mph (55 km/h)            Kings Dominion  Under construction
# 1086         58 mph (93 km/h)  Six Flags Magic Mountain  Under construction
#
#        Opening date                                  Type  \
# 1084  June 16, 2016                      Steel – Launched
# 1085            NaN  Steel – 4th Dimension – Wing Coaster
# 1086           2022                   Steel – Single-rail
#
#                      Manufacturer Height restriction  \
# 1084                       Vekoma   4[2] ft (122 cm)
# 1085    S&S – Sansei Technologies                NaN
# ...

# %%
df.dtypes
# Out:
# coaster_name                         str
# Length                               str
# Speed                                str
# Location                             str
# Status                               str
# Opening date                         str
# Type                                 str
# Manufacturer                         str
# Height restriction                   str
# Model                                str
# Height                               str
# Inversions                       float64
# Lift/launch system                   str
# Cost                                 str
# Trains                               str
# Park section                         str
# Duration                             str
# Capacity                             str
# G-force                              str
# Designer                             str
# Max vertical angle                   str
# Drop                                 str
# Soft opening date                    str
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   str
#  1   Length                         953 non-null    str
#  2   Speed                          937 non-null    str
#  3   Location                       1087 non-null   str
#  4   Status                         874 non-null    str
#  5   Opening date                   837 non-null    str
#  6   Type                           1087 non-null   str
#  7   Manufacturer                   1028 non-null   str
#  8   Height restriction             831 non-null    str
#  9   Model                          744 non-null    str
#  10  Height                         965 non-null    str
#  11  Inversions                     932 non-null    float64
#  12  Lift/launch system             795 non-null    str
# ...

# %%
df.isna().sum()
# Out:
# coaster_name                        0
# Length                            134
# Speed                             150
# Location                            0
# Status                            213
# Opening date                      250
# Type                                0
# Manufacturer                       59
# Height restriction                256
# Model                             343
# Height                            122
# Inversions                        155
# Lift/launch system                292
# Cost                              705
# Trains                            369
# Park section                      600
# Duration                          322
# Capacity                          512
# G-force                           725
# Designer                          509
# Max vertical angle                730
# Drop                              593
# Soft opening date                 991
# Fast Lane available              1018
# Replaced                          914
# ...

# %% [raw]
# Step 2: Data Preparation
# - Dropping irrelevant columns and rows
# - Identifying duplicated columns
# - Renaming columns
# - Feature creation

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df = df[['coaster_name', 
    # 'Length', 'Speed', 
    'Location', 'Status', 
    #'Opening date', 'Type', 
    'Manufacturer', 
    #'Height restriction', 'Model', 'Height',
     #  'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
      # 'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
       #'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
       #'Track layout', 'Fastrack available', 'Soft opening date.1',
       #'Closing date', 'Opened', 'Replaced by', 'Website',
      # 'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
       #'Single rider line available', 'Restraint Style',
       #'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', 
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
    #'height_value', 'height_unit', 
    'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
df
# Out:
#                                 coaster_name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        1087 non-null   str
#  1   Location            1087 non-null   str
#  2   Status              874 non-null    str
#  3   Manufacturer        1028 non-null   str
#  4   year_introduced     1087 non-null   int64
#  5   latitude            812 non-null    float64
#  6   longitude           812 non-null    float64
#  7   Type_Main           1087 non-null   str
#  8   opening_date_clean  837 non-null    str
#  9   speed_mph           937 non-null    float64
#  10  height_ft           171 non-null    float64
#  11  Inversions_clean    1087 non-null   int64
#  12  Gforce_clean        362 non-null    float64
# dtypes: float64(5), int64(2), str(6)
# memory usage: 187.4 KB

# %%
df['opening_date_clean'] = pd.to_datetime (df['opening_date_clean'])

# %%
df['opening_date_clean'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 1087 entries, 0 to 1086
# Series name: opening_date_clean
# Non-Null Count  Dtype
# --------------  -----
# 837 non-null    datetime64[us]
# dtypes: datetime64[us](1)
# memory usage: 8.6 KB

# %%
df = df.rename(columns={
    'coaster_name':'Coaster_Name',
                   'year_introduced':'Year_Introduced',
                   'opening_date_clean':'Opening_Date',
                   'speed_mph':'Speed_mph',
                   'height_ft':'Height_ft',
                   'Inversions_clean':'Inversions',
                   'Gforce_clean':'Gforce'
})

# %%
df.isna().sum()
# Out:
# Coaster_Name         0
# Location             0
# Status             213
# Manufacturer        59
# Year_Introduced      0
# latitude           275
# longitude          275
# Type_Main            0
# Opening_Date       250
# Speed_mph          150
# Height_ft          916
# Inversions           0
# Gforce             725
# dtype: int64

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Location, Status, Manufacturer, Year_Introduced, latitude, longitude, Type_Main, Opening_Date, Speed_mph, Height_ft, Inversions, Gforce]
# Index: []

# %%
# check for duplicate coaster name
df.loc[df.duplicated(subset=['Coaster_Name'])].head(5)
# Out:
#                           Coaster_Name             Location     Status  \
# 43               Crystal Beach Cyclone   Crystal Beach Park    Removed
# 60                         Derby Racer         Revere Beach    Removed
# 61         Blue Streak (Conneaut Lake)   Conneaut Lake Park     Closed
# 167      Big Thunder Mountain Railroad                Other        NaN
# 237  Thunder Run (Canada's Wonderland)  Canada's Wonderland  Operating
#
#                                           Manufacturer  Year_Introduced  \
# 43                                  Traver Engineering             1927
# 60                                      Fred W. Pearce             1937
# 61                                                 NaN             1938
# 167  Arrow Development (California and Florida)Dyna...             1980
# 237                                         Mack Rides             1986
#
#      latitude  longitude Type_Main Opening_Date  Speed_mph  Height_ft  \
# ...

# %%
df[df.duplicated(subset=['Coaster_Name'])].head(5)
# Out:
#                           Coaster_Name             Location     Status  \
# 43               Crystal Beach Cyclone   Crystal Beach Park    Removed
# 60                         Derby Racer         Revere Beach    Removed
# 61         Blue Streak (Conneaut Lake)   Conneaut Lake Park     Closed
# 167      Big Thunder Mountain Railroad                Other        NaN
# 237  Thunder Run (Canada's Wonderland)  Canada's Wonderland  Operating
#
#                                           Manufacturer  Year_Introduced  \
# 43                                  Traver Engineering             1927
# 60                                      Fred W. Pearce             1937
# 61                                                 NaN             1938
# 167  Arrow Development (California and Florida)Dyna...             1980
# 237                                         Mack Rides             1986
#
#      latitude  longitude Type_Main Opening_Date  Speed_mph  Height_ft  \
# ...

# %%
# check an example duplicate
df.query('Coaster_Name == "Crystal Beach Cyclone"')
# Out:
#              Coaster_Name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     Year_Introduced  latitude  longitude Type_Main Opening_Date  Speed_mph  \
# 39             1926   42.8617   -79.0598      Wood   1926-01-01       60.0
# 43             1927   42.8617   -79.0598      Wood   1926-01-01       60.0
#
#     Height_ft  Inversions  Gforce
# 39        NaN           0     4.0
# 43        NaN           0     4.0

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'latitude', 'longitude', 'Type_Main', 'Opening_Date', 'Speed_mph',
#        'Height_ft', 'Inversions', 'Gforce'],
#       dtype='str')

# %%
df = df.loc[~df.duplicated(subset=['Coaster_Name','Location','Opening_Date'])].reset_index(drop=True).copy()

# %%
df
# Out:
#                           Coaster_Name                   Location  \
# 0                Crystal Beach Cyclone         Crystal Beach Park
# 1                          Derby Racer               Revere Beach
# 2          Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 3        Big Thunder Mountain Railroad                      Other
# 4    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ..                                 ...                        ...
# 71            Untamed (Walibi Holland)             Walibi Holland
# 72                  Lil' Devil Coaster  Six Flags Great Adventure
# 73  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 74                          Iron Gwazi    Busch Gardens Tampa Bay
# 75           Tron Lightcycle Power Run                      Other
#
#                 Status                                       Manufacturer  \
# 0              Removed                                 Traver Engineering
# ...

# %% [raw]
# Step 3: Feature Understanding
# - Plotting feature distributions
# - Histogram, KDE, BOxplot

# %%
df['Year_Introduced'].value_counts()
# Out:
# Year_Introduced
# 2011    6
# 2019    6
# 2007    4
# 2009    4
# 2010    4
# 2014    4
# 1993    3
# 2005    3
# 2012    3
# 2015    3
# 1986    2
# 1989    2
# 2000    2
# 2002    2
# 2004    2
# 2008    2
# 2016    2
# 2017    2
# 2018    2
# 2021    2
# 2022    2
# 1927    1
# 1937    1
# 1938    1
# 1980    1
# 1988    1
# 1990    1
# 1995    1
# 1996    1
# 1998    1
# 1999    1
# 2001    1
# 2003    1
# 2006    1
# 2013    1
# Name: count, dtype: int64

# %%
ax = df['Year_Introduced'].value_counts().head(10).plot(kind='bar', title="Top 10 Years Coasters Introduced")
ax.set_xlabel('Year Introduced')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = df['Speed_mph'].plot(kind='hist', bins=20, title="Coaster Speed (mpg)")
ax.set_xlabel('Speed (mph)')
# Out:
# Text(0.5, 0, 'Speed (mph)')

# %%
ax = df['Speed_mph'].plot(kind='kde', title='Coaster Speed mph')
ax.set_xlabel('speed mph')
# Out:
# Text(0.5, 0, 'speed mph')

# %%
df['Type_Main'].value_counts()
# Out:
# Type_Main
# Steel    67
# Wood      7
# Other     2
# Name: count, dtype: int64

# %% [raw]
# Step 4: Feature Relationships
# - scatterplot
# - Heatmap
# - Pairplot
# - Groupby comparisons

# %%
df.plot(kind='scatter', x='Speed_mph', y='Height_ft', title='Coaster speed vs height')
plt.show()

# %%
sns.scatterplot(x='Speed_mph', y='Height_ft', hue = 'Year_Introduced', data=df)
# Out:
# <Axes: xlabel='Speed_mph', ylabel='Height_ft'>

# %%
sns.pairplot(df,
             vars=['Year_Introduced','Speed_mph',
                   'Height_ft','Inversions','Gforce'],
            hue='Type_Main')
plt.show()

# %%
df_corr = df[['Year_Introduced','Speed_mph',
    'Height_ft','Inversions','Gforce']].dropna().corr()
df_corr
# Out:
#                  Year_Introduced  Speed_mph  Height_ft  Inversions    Gforce
# Year_Introduced         1.000000   0.866396   0.576265    0.444912  0.922613
# Speed_mph               0.866396   1.000000   0.907380   -0.061741  0.606733
# Height_ft               0.576265   0.907380   1.000000   -0.475533  0.216429
# Inversions              0.444912  -0.061741  -0.475533    1.000000  0.755929
# Gforce                  0.922613   0.606733   0.216429    0.755929  1.000000

# %%
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %%
# What are the locations with the fastest roller coasters (minimum of 10)?
ax = df.query('Location != "Other"').groupby('Location')['Speed_mph'].agg(['mean','count']).sort_values('mean', ascending=False)['mean'].head(10).plot(kind='barh', figsize=(10,6), title="Average Coast Speed by Location")
ax.set_xlabel("Average Coaster Speed")
plt.show()
