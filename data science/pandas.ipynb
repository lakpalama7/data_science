# %% [markdown]
# # Pandas

# %% [raw]
# Series and dataFarme
# Loading datasets (csv, excel)
# Exploring data (head, info, describe)
# INdexing and filtering
# Sorting data

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-3.0.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.5.1-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# ...
# Using cached pandas-3.0.3-cp314-cp314-win_amd64.whl (9.9 MB)
# Using cached numpy-2.5.1-cp314-cp314-win_amd64.whl (12.6 MB)
# ...
#
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
# ...

# %%
# import pandas
import pandas as pd

# %% [raw]
# # pandas data strucute
# # Series, DataFrame, Panel
# Series - one d array, pd.Series()
# DataFrame -- 2 D array, pd.DataFrame()
# Panel - 3 D array , pd.Panel()

# %%
# series
pd.Series(range(2,24,3))
# Out:
# 0     2
# 1     5
# 2     8
# 3    11
# 4    14
# 5    17
# 6    20
# 7    23
# dtype: int64

# %%
# DataFrame
pd.DataFrame(range(1,24,3))
# Out:
#     0
# 0   1
# 1   4
# 2   7
# 3  10
# 4  13
# 5  16
# 6  19
# 7  22

# %% [markdown]
# # loading data

# %%
# loading csv file
df=pd.read_csv(r"D:\my project\codeit_datascience\data_science\regression\data science\used_cars_data_uncleaned.csv")
df.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0              72000       CNG       Manual      First    26.60   998.0
# 1              41000    Diesel       Manual      First    19.67  1582.0
# 2              46000    Petrol       Manual      First    18.20  1199.0
# 3              87000    Diesel       Manual      First    20.77  1248.0
# 4              40670    Diesel    Automatic     Second    15.20  1968.0
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# 2   88.7 bhp    5.0  8.61 Lakh   4.50
# ...

# %% [markdown]
# # Preview the data or Exploring data

# %%
# exploring head,tail, info, describe

# %%
df.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0              72000       CNG       Manual      First    26.60   998.0
# 1              41000    Diesel       Manual      First    19.67  1582.0
# 2              46000    Petrol       Manual      First    18.20  1199.0
# 3              87000    Diesel       Manual      First    20.77  1248.0
# 4              40670    Diesel    Automatic     Second    15.20  1968.0
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# 2   88.7 bhp    5.0  8.61 Lakh   4.50
# ...

# %%
df.head(2)
# Out:
#    S.No.                              Name Location  Year  Kilometers_Driven  \
# 0      0            Maruti Wagon R LXI CNG   Mumbai  2010              72000
# 1      1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015              41000
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine      Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0  58.16 bhp    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.2 bhp    5.0
#
#   New_Price  Price
# 0       NaN   1.75
# 1       NaN  12.50

# %%
df.tail()
# Out:
#       S.No.                                               Name   Location  \
# 7248   7248                  Volkswagen Vento Diesel Trendline  Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI     Mumbai
# 7250   7250                             Nissan Micra Diesel XV    Kolkata
# 7251   7251                             Volkswagen Polo GT TSI       Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...      Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  \
# 7248  2011              89411    Diesel       Manual      First    20.54
# 7249  2015              59000    Petrol    Automatic      First    17.21
# 7250  2012              28000    Diesel       Manual      First    23.08
# 7251  2013              52262    Petrol    Automatic      Third    17.20
# 7252  2014              72443    Diesel    Automatic      First    10.00
#
#       Engine      Power  Seats New_Price  Price
# ...

# %%
df.tail(2)
# Out:
#       S.No.                                               Name Location  Year  \
# 7251   7251                             Volkswagen Polo GT TSI     Pune  2013
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...    Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 7251              52262    Petrol    Automatic      Third     17.2  1197.0
# 7252              72443    Diesel    Automatic      First     10.0  2148.0
#
#           Power  Seats New_Price  Price
# 7251  103.6 bhp    5.0       NaN    NaN
# 7252    170 bhp    5.0       NaN    NaN

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   str
#  2   Location           7253 non-null   str
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   str
#  6   Transmission       7253 non-null   str
#  7   Owner_Type         7253 non-null   str
#  8   Mileage            7251 non-null   float64
#  9   Engine             7207 non-null   float64
#  10  Power              7207 non-null   str
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   str
#  13  Price              6019 non-null   float64
# dtypes: float64(4), int64(3), str(7)
# memory usage: 793.4 KB

# %%
df.describe()
# Out:
#              S.No.         Year  Kilometers_Driven      Mileage       Engine  \
# count  7253.000000  7253.000000       7.253000e+03  7251.000000  7207.000000
# mean   3626.000000  2013.365366       5.869906e+04    18.141580  1616.573470
# std    2093.905084     3.254421       8.442772e+04     4.562197   595.285137
# min       0.000000  1996.000000       1.710000e+02     0.000000    72.000000
# 25%    1813.000000  2011.000000       3.400000e+04    15.170000  1198.000000
# 50%    3626.000000  2014.000000       5.341600e+04    18.160000  1493.000000
# 75%    5439.000000  2016.000000       7.300000e+04    21.100000  1968.000000
# max    7252.000000  2019.000000       6.500000e+06    33.540000  5998.000000
#
#              Seats        Price
# count  7200.000000  6019.000000
# mean      5.279722     9.479468
# std       0.811660    11.187917
# min       0.000000     0.440000
# 25%       5.000000     3.500000
# 50%       5.000000     5.640000
# 75%       5.000000     9.950000
# ...

# %%
df.isna().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %%
df.columns
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='str')

# %%
# shape - return rows and column number
df.shape
# Out:
# (7253, 14)

# %%
df.ndim
# Out:
# 2

# %%
# Indexing and filtering
# iloc -- only numeric e.g df.iloc[row index, column index]
# loc --label e.g df.loc[row index, column name] e.g df.loc[index label, column name]
df.iloc[0:5] # using index and filter first 5 rows and all columsn
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0              72000       CNG       Manual      First    26.60   998.0
# 1              41000    Diesel       Manual      First    19.67  1582.0
# 2              46000    Petrol       Manual      First    18.20  1199.0
# 3              87000    Diesel       Manual      First    20.77  1248.0
# 4              40670    Diesel    Automatic     Second    15.20  1968.0
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# 2   88.7 bhp    5.0  8.61 Lakh   4.50
# ...

# %%
# filter first 5 rows and first 5 columns only
df.iloc[0:5,0:5]
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven
# 0              72000
# 1              41000
# 2              46000
# 3              87000
# 4              40670

# %%
df.loc[0:3,'Name']
# Out:
# 0              Maruti Wagon R LXI CNG
# 1    Hyundai Creta 1.6 CRDi SX Option
# 2                        Honda Jazz V
# 3                   Maruti Ertiga VDI
# Name: Name, dtype: str

# %%
df.loc[0:6:2, ['Name','Location','Year']]
# Out:
#                               Name    Location  Year
# 0           Maruti Wagon R LXI CNG      Mumbai  2010
# 2                     Honda Jazz V     Chennai  2011
# 4  Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 6           Nissan Micra Diesel XV      Jaipur  2013

# %%
df.head(2)
# Out:
#    S.No.                              Name Location  Year  Kilometers_Driven  \
# 0      0            Maruti Wagon R LXI CNG   Mumbai  2010              72000
# 1      1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015              41000
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine      Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0  58.16 bhp    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.2 bhp    5.0
#
#   New_Price  Price
# 0       NaN   1.75
# 1       NaN  12.50

# %%
# indexing is the process of selecting data using row number and column (name or number)

# %%
# selecting a single column
df['Year']
# Out:
# 0       2010
# 1       2015
# 2       2011
# 3       2012
# 4       2013
#         ...
# 7248    2011
# 7249    2015
# 7250    2012
# 7251    2013
# 7252    2014
# Name: Year, Length: 7253, dtype: int64

# %%
# selecting multiple column
df[['Name','Year']]
# Out:
#                                                    Name  Year
# 0                                Maruti Wagon R LXI CNG  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option  2015
# 2                                          Honda Jazz V  2011
# 3                                     Maruti Ertiga VDI  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  2013
# ...                                                 ...   ...
# 7248                  Volkswagen Vento Diesel Trendline  2011
# 7249                             Volkswagen Polo GT TSI  2015
# 7250                             Nissan Micra Diesel XV  2012
# 7251                             Volkswagen Polo GT TSI  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...  2014
#
# [7253 rows x 2 columns]

# %%
# loc()
df.loc[:,'Name']
# Out:
# 0                                  Maruti Wagon R LXI CNG
# 1                        Hyundai Creta 1.6 CRDi SX Option
# 2                                            Honda Jazz V
# 3                                       Maruti Ertiga VDI
# 4                         Audi A4 New 2.0 TDI Multitronic
#                               ...
# 7248                    Volkswagen Vento Diesel Trendline
# 7249                               Volkswagen Polo GT TSI
# 7250                               Nissan Micra Diesel XV
# 7251                               Volkswagen Polo GT TSI
# 7252    Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
# Name: Name, Length: 7253, dtype: str

# %%
df.loc[:,['Name','Year']]
# Out:
#                                                    Name  Year
# 0                                Maruti Wagon R LXI CNG  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option  2015
# 2                                          Honda Jazz V  2011
# 3                                     Maruti Ertiga VDI  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  2013
# ...                                                 ...   ...
# 7248                  Volkswagen Vento Diesel Trendline  2011
# 7249                             Volkswagen Polo GT TSI  2015
# 7250                             Nissan Micra Diesel XV  2012
# 7251                             Volkswagen Polo GT TSI  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...  2014
#
# [7253 rows x 2 columns]

# %%
df.loc[10:15,['Name','Year']]
# Out:
#                                 Name  Year
# 10                  Maruti Ciaz Zeta  2018
# 11       Honda City 1.5 V AT Sunroof  2012
# 12             Maruti Swift VDI BSIV  2015
# 13  Land Rover Range Rover 2.2L Pure  2014
# 14    Land Rover Freelander 2 TD4 SE  2012
# 15       Mitsubishi Pajero Sport 4X4  2014

# %%
# select column 'Year' and 'Tranmission' using loc
df.loc[:,['Year','Transmission']]
# Out:
#       Year Transmission
# 0     2010       Manual
# 1     2015       Manual
# 2     2011       Manual
# 3     2012       Manual
# 4     2013    Automatic
# ...    ...          ...
# 7248  2011       Manual
# 7249  2015    Automatic
# 7250  2012       Manual
# 7251  2013    Automatic
# 7252  2014    Automatic
#
# [7253 rows x 2 columns]

# %%
# selecting rows
# sample() -- select rows ramdomly
df.sample(n=20) # select 20 rows randomly
# Out:
#       S.No.                                            Name    Location  Year  \
# 4132   4132                          Maruti Swift Dzire ZXI     Chennai  2017
# 3066   3066  Audi A6 2011-2015 3.0 TDI Quattro Premium Plus        Pune  2012
# 2247   2247                          Maruti Swift Dzire VXI     Kolkata  2014
# 725     725                         Skoda Yeti Elegance 4X2      Jaipur  2016
# 4092   4092              Ford Classic 1.4 Duratorq Titanium     Chennai  2014
# 4236   4236                     Audi A4 35 TDI Premium Plus       Kochi  2015
# 833     833                     Hyundai i20 1.4 Asta Option   Bangalore  2017
# 7200   7200                                 Maruti Ritz LDi        Pune  2015
# 1176   1176                Fiat Linea Emotion Pack (Diesel)        Pune  2010
# 4258   4258                           Hyundai i10 Magna 1.2     Kolkata  2011
# 2616   2616                          Chevrolet Cruze LTZ AT      Mumbai  2013
# ...

# %%
df.sample(n=3)
# Out:
#       S.No.                                         Name   Location  Year  \
# 4894   4894                   Maruti Baleno Alpha Diesel  Hyderabad  2017
# 6907   6907  Ford Ecosport 1.0 Ecoboost Platinum Edition     Mumbai  2017
# 6422   6422                      Nissan Terrano XV D Pre       Pune  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 4894              24000    Diesel       Manual      First    27.39  1248.0
# 6907              15000    Petrol       Manual      First    18.88   999.0
# 6422              75000    Diesel       Manual      First    19.64  1461.0
#
#            Power  Seats   New_Price  Price
# 4894      74 bhp    5.0  10.63 Lakh    8.4
# 6907  123.24 bhp    5.0         NaN    NaN
# 6422   108.5 bhp    5.0  16.82 Lakh    NaN

# %%
# selet 1% of data from the dataset
df.sample(frac=0.01)
# Out:
#       S.No.                                          Name    Location  Year  \
# 710     710       Renault Duster 85PS Diesel RxL Optional      Jaipur  2014
# 1069   1069                        Maruti Swift Dzire VDI     Kolkata  2014
# 1358   1358                               Maruti Alto LXi  Coimbatore  2012
# 4772   4772                              Maruti Swift VDI     Kolkata  2014
# 6942   6942  Mercedes-Benz New C-Class C 250 CDI Elegance        Pune  2010
# ...     ...                                           ...         ...   ...
# 4515   4515   Toyota Innova 2.5 G (Diesel) 7 Seater BS IV        Pune  2009
# 547     547                   BMW 5 Series 2003-2012 520d   Ahmedabad  2012
# 2690   2690                     Audi A8 L 3.0 TDI quattro   Bangalore  2009
# 4077   4077                     Maruti Baleno LXI - BSIII       Kochi  2006
# 4019   4019                   Hyundai i20 Sportz 1.4 CRDi      Jaipur  2013
#
# ...

# %%
df.sample(frac=0.001)
# Out:
#       S.No.                                               Name    Location  \
# 235     235                     Toyota Innova Crysta 2.8 GX AT       Kochi
# 6445   6445                        Maruti Swift VDI BSIV W ABS  Coimbatore
# 5440   5440                        Honda Jazz 1.2 V CVT i VTEC  Coimbatore
# 56       56                                   Renault KWID RXT       Kochi
# 3244   3244                Jeep Compass 2.0 Limited Option 4X4     Kolkata
# 1281   1281  Hyundai Grand i10 CRDi Sportz Celebration Edition       Kochi
# 1606   1606                              Honda Amaze VX i-DTEC       Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  \
# 235   2019              14165    Diesel    Automatic      First    11.36
# 6445  2016              69564    Diesel       Manual      First    17.80
# 5440  2017              66507    Petrol    Automatic     Second    19.00
# 56    2017              16542    Petrol       Manual      First    25.17
# ...

# %%
# select row index from 41 to 61
df.iloc[41:62, :]
# Out:
#     S.No.                                        Name    Location  Year  \
# 41     41                             Tata Nano LX SE       Kochi  2014
# 42     42   Mahindra KUV 100 mFALCON D75 K8 Dual Tone  Coimbatore  2017
# 43     43              Hyundai i20 Magna Optional 1.2       Kochi  2014
# 44     44            Hyundai Elantra 2.0 SX Option AT   Bangalore  2014
# 45     45                   Toyota Corolla Altis G AT      Mumbai  2016
# 46     46                        Hyundai Elantra CRDi   Ahmedabad  2008
# 47     47              Toyota Innova Crysta 2.7 GX MT   Bangalore  2012
# 48     48                    Hyundai Xcent 1.1 CRDi S      Jaipur  2014
# 49     49                       Mahindra Thar CRDe AC      Jaipur  2012
# 50     50        Audi A4 2.0 TDI 177 Bhp Premium Plus       Kochi  2015
# 51     51                            Maruti Swift LDI       Delhi  2014
# 52     52                       Maruti Swift Ldi BSIV     Kolkata  2014
# ...

# %%
# select all rows in index 10 to 99, in step 3
df.loc[10:100:3,['Year','Transmission']]
# Out:
#      Year Transmission
# 10   2018       Manual
# 13   2014    Automatic
# 16   2016       Manual
# 19   2014    Automatic
# 22   2015    Automatic
# 25   2012       Manual
# 28   2018       Manual
# 31   2012       Manual
# 34   2014       Manual
# 37   2017       Manual
# 40   2008       Manual
# 43   2014       Manual
# 46   2008       Manual
# 49   2012       Manual
# 52   2014       Manual
# 55   2015       Manual
# 58   2010    Automatic
# 61   2010       Manual
# 64   2016       Manual
# 67   2019    Automatic
# 70   2008    Automatic
# 73   2015       Manual
# 76   2008       Manual
# 79   2005       Manual
# 82   2016       Manual
# 85   2009       Manual
# 88   2016       Manual
# 91   2014       Manual
# 94   2014       Manual
# 97   2010       Manual
# 100  2011       Manual

# %%
df.iloc[10:20:3,5:10]
# Out:
#    Fuel_Type Transmission Owner_Type  Mileage  Engine
# 10    Petrol       Manual      First    21.56  1462.0
# 13    Diesel    Automatic      First    12.70  2179.0
# 16    Diesel       Manual      First    25.80  1498.0
# 19    Diesel    Automatic      First    14.84  2143.0

# %% [markdown]
# # Filter

# %%
# select data according to the condition
df.head(2)
# Out:
#    S.No.                              Name Location  Year  Kilometers_Driven  \
# 0      0            Maruti Wagon R LXI CNG   Mumbai  2010              72000
# 1      1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015              41000
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine      Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0  58.16 bhp    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.2 bhp    5.0
#
#   New_Price  Price
# 0       NaN   1.75
# 1       NaN  12.50

# %%
# select all the data where 'Mileage' is >=30
con = df['Mileage']>=30
df[con]
# Out:
#       S.No.                               Name Location  Year  \
# 1269   1269  Maruti Alto 800 2016-2019 CNG LXI   Mumbai  2018
# 1332   1332             Maruti Wagon R CNG LXI     Pune  2013
# 2059   2059             Maruti Wagon R CNG LXI   Mumbai  2013
# 2371   2371             Maruti Wagon R CNG LXI     Pune  2014
# 2701   2701          Maruti Celerio CNG VXI MT    Kochi  2016
# 3119   3119   Maruti Alto K10 LXI CNG Optional    Kochi  2018
# 3129   3129             Maruti Wagon R CNG LXI    Delhi  2014
# 3553   3553  Maruti Alto 800 2016-2019 CNG LXI     Pune  2015
# 3869   3869  Maruti Alto 800 2016-2019 CNG LXI    Delhi  2012
# 4141   4141             Maruti Wagon R CNG LXI   Mumbai  2014
# 4769   4769  Maruti Alto 800 2016-2019 CNG LXI    Kochi  2017
# 5178   5178          Maruti Celerio CNG VXI MT    Delhi  2015
# 5710   5710            Maruti Alto 800 CNG LXI   Mumbai  2013
# 5935   5935            Maruti Alto K10 LXI CNG     Pune  2015
# ...

# %%
# filter data with multiple conditions
# select all data mileage >=30 and tranmission ='manual'
con1 = df['Mileage']>=30
con2 = df['Transmission']=='Manual'
df[con1 & con2]
# Out:
#       S.No.                               Name Location  Year  \
# 1269   1269  Maruti Alto 800 2016-2019 CNG LXI   Mumbai  2018
# 1332   1332             Maruti Wagon R CNG LXI     Pune  2013
# 2059   2059             Maruti Wagon R CNG LXI   Mumbai  2013
# 2371   2371             Maruti Wagon R CNG LXI     Pune  2014
# 2701   2701          Maruti Celerio CNG VXI MT    Kochi  2016
# 3119   3119   Maruti Alto K10 LXI CNG Optional    Kochi  2018
# 3129   3129             Maruti Wagon R CNG LXI    Delhi  2014
# 3553   3553  Maruti Alto 800 2016-2019 CNG LXI     Pune  2015
# 3869   3869  Maruti Alto 800 2016-2019 CNG LXI    Delhi  2012
# 4141   4141             Maruti Wagon R CNG LXI   Mumbai  2014
# 4769   4769  Maruti Alto 800 2016-2019 CNG LXI    Kochi  2017
# 5178   5178          Maruti Celerio CNG VXI MT    Delhi  2015
# 5710   5710            Maruti Alto 800 CNG LXI   Mumbai  2013
# 5935   5935            Maruti Alto K10 LXI CNG     Pune  2015
# ...

# %%
df[con1 & con2].head()
# Out:
#       S.No.                               Name Location  Year  \
# 1269   1269  Maruti Alto 800 2016-2019 CNG LXI   Mumbai  2018
# 1332   1332             Maruti Wagon R CNG LXI     Pune  2013
# 2059   2059             Maruti Wagon R CNG LXI   Mumbai  2013
# 2371   2371             Maruti Wagon R CNG LXI     Pune  2014
# 2701   2701          Maruti Celerio CNG VXI MT    Kochi  2016
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 1269              10600       CNG       Manual      First    33.44   796.0
# 1332              79494       CNG       Manual      First    33.54   998.0
# 2059              54000       CNG       Manual      First    33.54   998.0
# 2371              29202       CNG       Manual      First    33.54   998.0
# 2701              70536       CNG       Manual      First    31.79   998.0
#
#           Power  Seats  New_Price  Price
# 1269   40.3 bhp    4.0        NaN   3.50
# 1332  67.04 bhp    5.0  5.54 Lakh   2.96
# ...

# %%
data = df[con1 & con2]
data[['Name','Year']]
# Out:
#                                    Name  Year
# 1269  Maruti Alto 800 2016-2019 CNG LXI  2018
# 1332             Maruti Wagon R CNG LXI  2013
# 2059             Maruti Wagon R CNG LXI  2013
# 2371             Maruti Wagon R CNG LXI  2014
# 2701          Maruti Celerio CNG VXI MT  2016
# 3119   Maruti Alto K10 LXI CNG Optional  2018
# 3129             Maruti Wagon R CNG LXI  2014
# 3553  Maruti Alto 800 2016-2019 CNG LXI  2015
# 3869  Maruti Alto 800 2016-2019 CNG LXI  2012
# 4141             Maruti Wagon R CNG LXI  2014
# 4769  Maruti Alto 800 2016-2019 CNG LXI  2017
# 5178          Maruti Celerio CNG VXI MT  2015
# 5710            Maruti Alto 800 CNG LXI  2013
# 5935            Maruti Alto K10 LXI CNG  2015
# 6019            Maruti Alto K10 LXI CNG  2014
# 6538            Maruti Alto K10 LXI CNG  2015
# 6788   Maruti Alto K10 LXI CNG Optional  2017
# 6958            Maruti Alto 800 CNG LXI  2013

# %%
df[con1 & con2][['Name','Year']]
# Out:
#                                    Name  Year
# 1269  Maruti Alto 800 2016-2019 CNG LXI  2018
# 1332             Maruti Wagon R CNG LXI  2013
# 2059             Maruti Wagon R CNG LXI  2013
# 2371             Maruti Wagon R CNG LXI  2014
# 2701          Maruti Celerio CNG VXI MT  2016
# 3119   Maruti Alto K10 LXI CNG Optional  2018
# 3129             Maruti Wagon R CNG LXI  2014
# 3553  Maruti Alto 800 2016-2019 CNG LXI  2015
# 3869  Maruti Alto 800 2016-2019 CNG LXI  2012
# 4141             Maruti Wagon R CNG LXI  2014
# 4769  Maruti Alto 800 2016-2019 CNG LXI  2017
# 5178          Maruti Celerio CNG VXI MT  2015
# 5710            Maruti Alto 800 CNG LXI  2013
# 5935            Maruti Alto K10 LXI CNG  2015
# 6019            Maruti Alto K10 LXI CNG  2014
# 6538            Maruti Alto K10 LXI CNG  2015
# 6788   Maruti Alto K10 LXI CNG Optional  2017
# 6958            Maruti Alto 800 CNG LXI  2013

# %%
df.columns
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='str')

# %%
df['Location'].unique()
# Out:
# <StringArray>
# [    'Mumbai',       'Pune',    'Chennai', 'Coimbatore',  'Hyderabad',
#      'Jaipur',      'Kochi',    'Kolkata',      'Delhi',  'Bangalore',
#   'Ahmedabad']
# Length: 11, dtype: str

# %%
location = df[df['Location']=='Pune']
location
# Out:
#       S.No.                                       Name Location  Year  \
# 1         1           Hyundai Creta 1.6 CRDi SX Option     Pune  2015
# 8         8        Volkswagen Vento Diesel Comfortline     Pune  2013
# 14       14             Land Rover Freelander 2 TD4 SE     Pune  2012
# 38       38           Mercedes-Benz M-Class ML 350 CDI     Pune  2013
# 63       63  Mercedes-Benz New C-Class 200 CDI Classic     Pune  2011
# ...     ...                                        ...      ...   ...
# 7200   7200                            Maruti Ritz LDi     Pune  2015
# 7228   7228         Tata Tiago 1.05 Revotorq XT Option     Pune  2016
# 7230   7230                      Hyundai i20 1.2 Spotz     Pune  2014
# 7244   7244                      Chevrolet Aveo 1.4 LS     Pune  2009
# 7251   7251                     Volkswagen Polo GT TSI     Pune  2013
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# ...

# %%
location = df[df['Location']=='Pune']['Name']
location
# Out:
# 1                Hyundai Creta 1.6 CRDi SX Option
# 8             Volkswagen Vento Diesel Comfortline
# 14                 Land Rover Freelander 2 TD4 SE
# 38               Mercedes-Benz M-Class ML 350 CDI
# 63      Mercedes-Benz New C-Class 200 CDI Classic
#                           ...
# 7200                              Maruti Ritz LDi
# 7228           Tata Tiago 1.05 Revotorq XT Option
# 7230                        Hyundai i20 1.2 Spotz
# 7244                        Chevrolet Aveo 1.4 LS
# 7251                       Volkswagen Polo GT TSI
# Name: Name, Length: 765, dtype: str

# %% [raw]
# # Filter data with multiple condition OR

# %%
# select all data where mileage >=32 or 'Fuel_type' is 'LPG'
df.Mileage.max()
# Out:
# np.float64(33.54)

# %%
df.Fuel_Type.unique()
# Out:
# <StringArray>
# ['CNG', 'Diesel', 'Petrol', 'LPG', 'Electric']
# Length: 5, dtype: str

# %%
con1 = df['Mileage']>=32
con2 = df['Fuel_Type']=='LPG'
df[con1 | con2]
# Out:
#       S.No.                               Name   Location  Year  \
# 5         5    Hyundai EON LPG Era Plus Option  Hyderabad  2012
# 936     936        Maruti Wagon R LXI LPG BSIV  Hyderabad  2012
# 987     987       Maruti Wagon R LXI DUO BSIII     Mumbai  2008
# 1269   1269  Maruti Alto 800 2016-2019 CNG LXI     Mumbai  2018
# 1332   1332             Maruti Wagon R CNG LXI       Pune  2013
# 2059   2059             Maruti Wagon R CNG LXI     Mumbai  2013
# 2278   2278        Hyundai Santro Xing GLS LPG       Pune  2010
# 2371   2371             Maruti Wagon R CNG LXI       Pune  2014
# 2385   2385        Hyundai Santro Xing GLS LPG  Hyderabad  2011
# 2436   2436              Hyundai i10 Magna LPG     Jaipur  2012
# 2941   2941    Hyundai Santro Xing GL Plus LPG  Hyderabad  2014
# 3119   3119   Maruti Alto K10 LXI CNG Optional      Kochi  2018
# 3129   3129             Maruti Wagon R CNG LXI      Delhi  2014
# 3553   3553  Maruti Alto 800 2016-2019 CNG LXI       Pune  2015
# ...

# %%
# selec only name, location, year
df[con1 | con2][['Name','Location','Year']].head()
# Out:
#                                    Name   Location  Year
# 5       Hyundai EON LPG Era Plus Option  Hyderabad  2012
# 936         Maruti Wagon R LXI LPG BSIV  Hyderabad  2012
# 987        Maruti Wagon R LXI DUO BSIII     Mumbai  2008
# 1269  Maruti Alto 800 2016-2019 CNG LXI     Mumbai  2018
# 1332             Maruti Wagon R CNG LXI       Pune  2013

# %%
# using not condition - select all values except transmission is Manual
df[df['Transmission']!='Manual']
# Out:
#       S.No.                                               Name    Location  \
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# 7         7                  Toyota Innova Crysta 2.8 GX AT 8S      Mumbai
# 11       11                        Honda City 1.5 V AT Sunroof     Kolkata
# 13       13                   Land Rover Range Rover 2.2L Pure       Delhi
# 14       14                     Land Rover Freelander 2 TD4 SE        Pune
# ...     ...                                                ...         ...
# 7241   7241                            BMW 5 Series 525d Sedan       Delhi
# 7246   7246                          Hyundai Grand i10 AT Asta  Coimbatore
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %% [markdown]
# # sorting data

# %%
# sort the data on the basis of mileage in asceding order
df.sort_values(by='Mileage')
# Out:
#       S.No.                                 Name   Location  Year  \
# 7226   7226               Hyundai Santro Xing GL  Ahmedabad  2014
# 5647   5647               Toyota Qualis Fleet A3     Mumbai  2001
# 707     707  Mercedes-Benz M-Class ML 350 4Matic       Pune  2014
# 6697   6697               Hyundai Santro Xing XL     Jaipur  2007
# 6093   6093               Hyundai Santro Xing XL  Bangalore  2007
# ...     ...                                  ...        ...   ...
# 2059   2059               Maruti Wagon R CNG LXI     Mumbai  2013
# 2371   2371               Maruti Wagon R CNG LXI       Pune  2014
# 1332   1332               Maruti Wagon R CNG LXI       Pune  2013
# 4446   4446                 Mahindra E Verito D4    Chennai  2016
# 4904   4904            Toyota Prius 2009-2016 Z4     Mumbai  2011
#
#       Kilometers_Driven Fuel_Type Transmission      Owner_Type  Mileage  \
# 7226              41000    Petrol       Manual           First     0.00
# ...

# %%
# sort values in decending order
df.sort_values(by='Mileage', ascending=False)['Mileage']
# Out:
# 2371    33.54
# 4141    33.54
# 3129    33.54
# 1332    33.54
# 2059    33.54
#         ...
# 5016     0.00
# 7226     0.00
# 14       0.00
# 4446      NaN
# 4904      NaN
# Name: Mileage, Length: 7253, dtype: float64

# %%
# multi level sorting
# sort values by location and mileage
df.sort_values(by=['Location','Mileage'])[['Location','Mileage']]
# Out:
#        Location  Mileage
# 194   Ahmedabad     0.00
# 3061  Ahmedabad     0.00
# 5374  Ahmedabad     0.00
# 5875  Ahmedabad     0.00
# 6090  Ahmedabad     0.00
# ...         ...      ...
# 5940       Pune    28.40
# 5935       Pune    32.26
# 3553       Pune    33.44
# 1332       Pune    33.54
# 2371       Pune    33.54
#
# [7253 rows x 2 columns]

# %%
df.sort_values(by=['Location','Mileage'], ascending=False)
# Out:
#       S.No.                                      Name   Location  Year  \
# 1332   1332                    Maruti Wagon R CNG LXI       Pune  2013
# 2371   2371                    Maruti Wagon R CNG LXI       Pune  2014
# 3553   3553         Maruti Alto 800 2016-2019 CNG LXI       Pune  2015
# 5935   5935                   Maruti Alto K10 LXI CNG       Pune  2015
# 1756   1756                     Maruti Swift DDiS VDI       Pune  2008
# ...     ...                                       ...        ...   ...
# 5374   5374       Mercedes-Benz M-Class ML 350 4Matic  Ahmedabad  2012
# 5875   5875  Mercedes-Benz C-Class Progressive C 220d  Ahmedabad  2019
# 6090   6090                    Hyundai Santro Xing GL  Ahmedabad  2013
# 6205   6205                    Hyundai Santro Xing GL  Ahmedabad  2007
# 7226   7226                    Hyundai Santro Xing GL  Ahmedabad  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# ...

# %% [markdown]
# # Must know functions:

# %%
# value_counts()
# sum()
# max()
# mean()
# unique()
# std()

# %%
# value_counts() ---counts frequeency of value
df.head(2)
# Out:
#    S.No.                              Name Location  Year  Kilometers_Driven  \
# 0      0            Maruti Wagon R LXI CNG   Mumbai  2010              72000
# 1      1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015              41000
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine      Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0  58.16 bhp    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.2 bhp    5.0
#
#   New_Price  Price
# 0       NaN   1.75
# 1       NaN  12.50

# %%
df['Location'].value_counts()
# Out:
# Location
# Mumbai        949
# Hyderabad     876
# Coimbatore    772
# Kochi         772
# Pune          765
# Delhi         660
# Kolkata       654
# Chennai       591
# Jaipur        499
# Bangalore     440
# Ahmedabad     275
# Name: count, dtype: int64

# %%
# unique()
df['Transmission'].unique()
# Out:
# <StringArray>
# ['Manual', 'Automatic']
# Length: 2, dtype: str

# %%
df['Location'].value_counts()
# Out:
# Location
# Mumbai        949
# Hyderabad     876
# Coimbatore    772
# Kochi         772
# Pune          765
# Delhi         660
# Kolkata       654
# Chennai       591
# Jaipur        499
# Bangalore     440
# Ahmedabad     275
# Name: count, dtype: int64

# %%
df['Location'].unique()
# Out:
# <StringArray>
# [    'Mumbai',       'Pune',    'Chennai', 'Coimbatore',  'Hyderabad',
#      'Jaipur',      'Kochi',    'Kolkata',      'Delhi',  'Bangalore',
#   'Ahmedabad']
# Length: 11, dtype: str

# %%
df['Location'].nunique()
# Out:
# 11

# %%
df['Fuel_Type'].unique()
# Out:
# <StringArray>
# ['CNG', 'Diesel', 'Petrol', 'LPG', 'Electric']
# Length: 5, dtype: str

# %%
df['Fuel_Type'].nunique()
# Out:
# 5

# %%
df['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Diesel      3852
# Petrol      3325
# CNG           62
# LPG           12
# Electric       2
# Name: count, dtype: int64

# %%
#max()
df.Mileage.max()
# Out:
# np.float64(33.54)

# %%
df.Mileage.min()
# Out:
# np.float64(0.0)

# %%
df.Mileage.mean()
# Out:
# np.float64(18.141580471659083)

# %%
df.Mileage.std()
# Out:
# np.float64(4.562196601725892)

# %%
df.Mileage.median()
# Out:
# np.float64(18.16)

# %%
df.Mileage.quantile(0.25)
# Out:
# np.float64(15.17)

# %%
df.Mileage.quantile(0.50)
# Out:
# np.float64(18.16)

# %%
df.Mileage.quantile(0.75)
# Out:
# np.float64(21.1)

# %%
df.Mileage.sum()
# Out:
# np.float64(131544.6)

# %%
# find the top most selling Trasmission
df['Transmission'].value_counts()
# Out:
# Transmission
# Manual       5204
# Automatic    2049
# Name: count, dtype: int64

# %%
# find top most selling car
df.Name.value_counts().head()
# Out:
# Name
# Mahindra XUV500 W8 2WD    55
# Maruti Swift VDI          49
# Maruti Swift Dzire VDI    42
# Honda City 1.5 S MT       39
# Maruti Swift VDI BSIV     37
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#    S.No.                              Name Location  Year  Kilometers_Driven  \
# 0      0            Maruti Wagon R LXI CNG   Mumbai  2010              72000
# 1      1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015              41000
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine      Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0  58.16 bhp    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.2 bhp    5.0
#
#   New_Price  Price
# 0       NaN   1.75
# 1       NaN  12.50

# %% [markdown]
# # dropping, Arranging and renaming columns

# %%
# delete (drop) column
df.columns
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='str')

# %%
df=df.drop('S.No.', axis=1)

# %%
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine      Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0  58.16 bhp    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.2 bhp    5.0
# 2    Petrol       Manual      First    18.20  1199.0   88.7 bhp    5.0
# 3    Diesel       Manual      First    20.77  1248.0  88.76 bhp    7.0
# 4    Diesel    Automatic     Second    15.20  1968.0  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# 2  8.61 Lakh   4.50
# ...

# %%
# drop multiple columns
# drop year, owner_type
df.drop(['Year','Owner_Type'], axis=1, inplace= True)

# %%
df.head()
# Out:
#                                Name    Location  Kilometers_Driven Fuel_Type  \
# 0            Maruti Wagon R LXI CNG      Mumbai              72000       CNG
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune              41000    Diesel
# 2                      Honda Jazz V     Chennai              46000    Petrol
# 3                 Maruti Ertiga VDI     Chennai              87000    Diesel
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore              40670    Diesel
#
#   Transmission  Mileage  Engine      Power  Seats  New_Price  Price
# 0       Manual    26.60   998.0  58.16 bhp    5.0        NaN   1.75
# 1       Manual    19.67  1582.0  126.2 bhp    5.0        NaN  12.50
# 2       Manual    18.20  1199.0   88.7 bhp    5.0  8.61 Lakh   4.50
# 3       Manual    20.77  1248.0  88.76 bhp    7.0        NaN   6.00
# 4    Automatic    15.20  1968.0  140.8 bhp    5.0        NaN  17.74

# %%
# REname col
df.columns
# Out:
# Index(['Name', 'Location', 'Kilometers_Driven', 'Fuel_Type', 'Transmission',
#        'Mileage', 'Engine', 'Power', 'Seats', 'New_Price', 'Price'],
#       dtype='str')

# %%
df.rename(columns={'Kilometers_Driven':'run','Fuel_Type':'fule','New_Price':'price'}, inplace=True)

# %%
df.head()
# Out:
#                                Name    Location    run    fule Transmission  \
# 0            Maruti Wagon R LXI CNG      Mumbai  72000     CNG       Manual
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  41000  Diesel       Manual
# 2                      Honda Jazz V     Chennai  46000  Petrol       Manual
# 3                 Maruti Ertiga VDI     Chennai  87000  Diesel       Manual
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  40670  Diesel    Automatic
#
#    Mileage  Engine      Power  Seats      price  Price
# 0    26.60   998.0  58.16 bhp    5.0        NaN   1.75
# 1    19.67  1582.0  126.2 bhp    5.0        NaN  12.50
# 2    18.20  1199.0   88.7 bhp    5.0  8.61 Lakh   4.50
# 3    20.77  1248.0  88.76 bhp    7.0        NaN   6.00
# 4    15.20  1968.0  140.8 bhp    5.0        NaN  17.74

# %%
# column arrange
df.columns
# Out:
# Index(['Name', 'Location', 'run', 'fule', 'Transmission', 'Mileage', 'Engine',
#        'Power', 'Seats', 'price', 'Price'],
#       dtype='str')

# %%
cols=['Location','run','Name','fule','Transmission', 'Mileage', 'Engine',
       'Power', 'Seats', 'price', 'Price']

# %%
# dataframe 'df' columns are arranged
df = df[cols]

# %%
df.head()
# Out:
#      Location    run                              Name    fule Transmission  \
# 0      Mumbai  72000            Maruti Wagon R LXI CNG     CNG       Manual
# 1        Pune  41000  Hyundai Creta 1.6 CRDi SX Option  Diesel       Manual
# 2     Chennai  46000                      Honda Jazz V  Petrol       Manual
# 3     Chennai  87000                 Maruti Ertiga VDI  Diesel       Manual
# 4  Coimbatore  40670   Audi A4 New 2.0 TDI Multitronic  Diesel    Automatic
#
#    Mileage  Engine      Power  Seats      price  Price
# 0    26.60   998.0  58.16 bhp    5.0        NaN   1.75
# 1    19.67  1582.0  126.2 bhp    5.0        NaN  12.50
# 2    18.20  1199.0   88.7 bhp    5.0  8.61 Lakh   4.50
# 3    20.77  1248.0  88.76 bhp    7.0        NaN   6.00
# 4    15.20  1968.0  140.8 bhp    5.0        NaN  17.74

# %%
# save the file
df.to_csv('cardata_saved.csv',index=False)
